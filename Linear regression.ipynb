# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

# %%
df=pd.read_csv('Dhaka Rent.csv')
df
# Out:
#     area   rent
# 0   2000  31500
# 1   2100  35000
# 2   2500  41050
# 3   2250  36100
# 4   3000  52100
# 5   1900  32500
# 6   1500  20000
# 7   1850  24500
# 8   2700  48000
# 9   2100  31000
# 10  2150  34500
# 11  2100  32000
# 12  2100  34500
# 13  2510  40050
# 14  2250  34100
# 15  3100  51500
# 16  1800  30500
# 17  1550  21000
# 18  1800  25000
# 19  2700  47000
# 20  2110  31500
# 21  2100  33500
# 22  3500  70000
# 23  1200  20000
# 24  2800  50000
# 25  3100  53000
# 26  2750  48000
# 27  1800  25000
# 28  2200  31460
# 29  3100  51400
# 30  2100  33500
# 31  2100  35010
# 32  2500  41100
# 33  2250  35100
# 34  3000  52200
# 35  1900  32300
# 36  1500  20200
# 37  1850  24000
# 38  2700  47500
# 39  2100  31500
# 40  2150  34400
# 41  2100  32020
# 42  2100  34700
# 43  2510  40000
# 44  2250  35000
# 45  3100  51000
# 46  1800  30000
# 47  1550  21500
# 48  1800  25500
# 49  2700  47500
# 50  2110  31000
# 51  2100  33000
# 52  3500  70500
# 53  1200  20100
# ...

# %%
df.head()               #show first 5 value
# Out:
#    area   rent
# 0  2000  31500
# 1  2100  35000
# 2  2500  41050
# 3  2250  36100
# 4  3000  52100

# %%
df.tail()              #show last 5 value
# Out:
#     area   rent
# 55  3100  54000
# 56  2750  48500
# 57  1800  25100
# 58  2200  31560
# 59  3100  51600

# %%
df.head(2)          #show fast 2 value
# Out:
#    area   rent
# 0  2000  31500
# 1  2100  35000

# %%
df.area              #show area
# Out:
# 0     2000
# 1     2100
# 2     2500
# 3     2250
# 4     3000
# 5     1900
# 6     1500
# 7     1850
# 8     2700
# 9     2100
# 10    2150
# 11    2100
# 12    2100
# 13    2510
# 14    2250
# 15    3100
# 16    1800
# 17    1550
# 18    1800
# 19    2700
# 20    2110
# 21    2100
# 22    3500
# 23    1200
# 24    2800
# 25    3100
# 26    2750
# 27    1800
# 28    2200
# 29    3100
# 30    2100
# 31    2100
# 32    2500
# 33    2250
# 34    3000
# 35    1900
# 36    1500
# 37    1850
# 38    2700
# 39    2100
# 40    2150
# 41    2100
# 42    2100
# 43    2510
# 44    2250
# 45    3100
# 46    1800
# 47    1550
# 48    1800
# 49    2700
# 50    2110
# 51    2100
# 52    3500
# 53    1200
# 54    2800
# 55    3100
# 56    2750
# 57    1800
# 58    2200
# 59    3100
# Name: area, dtype: int64

# %%
df.rent           #show rent
# Out:
# 0     31500
# 1     35000
# 2     41050
# 3     36100
# 4     52100
# 5     32500
# 6     20000
# 7     24500
# 8     48000
# 9     31000
# 10    34500
# 11    32000
# 12    34500
# 13    40050
# 14    34100
# 15    51500
# 16    30500
# 17    21000
# 18    25000
# 19    47000
# 20    31500
# 21    33500
# 22    70000
# 23    20000
# 24    50000
# 25    53000
# 26    48000
# 27    25000
# 28    31460
# 29    51400
# 30    33500
# 31    35010
# 32    41100
# 33    35100
# 34    52200
# 35    32300
# 36    20200
# 37    24000
# 38    47500
# 39    31500
# 40    34400
# 41    32020
# 42    34700
# 43    40000
# 44    35000
# 45    51000
# 46    30000
# 47    21500
# 48    25500
# 49    47500
# 50    31000
# 51    33000
# 52    70500
# 53    20100
# 54    51000
# 55    54000
# 56    48500
# 57    25100
# 58    31560
# 59    51600
# Name: rent, dtype: int64

# %%
df[4:5]
# Out:
#    area   rent
# 4  3000  52100

# %%
df[7:9]               #show 6 row value
# Out:
#    area   rent
# 7  1850  24500
# 8  2700  48000

# %%
df.area.mean()           # average of area
# Out:
# 2289.0

# %%
df.rent.mean()               #average of rent
# Out:
# 37269.166666666664

# %%
df.describe()
# Out:
#               area          rent
# count    60.000000     60.000000
# mean   2289.000000  37269.166667
# std     538.880509  11770.736234
# min    1200.000000  20000.000000
# 25%    1900.000000  31000.000000
# 50%    2130.000000  34450.000000
# 75%    2700.000000  47625.000000
# max    3500.000000  70500.000000

# %%
df.isnull().sum()          # kno null value thakle ta sum kre dekhabe    
                           #aykhane kno null value neay
# Out:
# area    0
# rent    0
# dtype: int64

# %%
plt.scatter(df.area,df.rent)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-22-7c94b826b370> in <module>
#       1 plt.scatter(df.area,df.rent)
# ----> 2 plt.xlable('area')
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'xlable'

# %%
x = df[['area']]
y =df[['rent']]

# %%
y.head()
# Out:
#     rent
# 0  31500
# 1  35000
# 2  41050
# 3  36100
# 4  52100

# %%
x.head()
# Out:
#    area
# 0  2000
# 1  2100
# 2  2500
# 3  2250
# 4  3000

# %%
from sklearn.model_selection import train_test_split as tts

# %%
xtrain,xtest,ytrain,ytest=tts(x,y,test_size=.30)

# %%
xtrain.head()
# Out:
#     area
# 49  2700
# 48  1800
# 34  3000
# 37  1850
# 13  2510

# %%
ytrain.head()
# Out:
#      rent
# 49  47500
# 48  25500
# 34  52200
# 37  24000
# 13  40050

# %%
from sklearn.linear_model import LinearRegression

# %%
reg = LinearRegression()

# %%
reg.fit(xtrain,ytrain)
# Out:
# LinearRegression()

# %%
m = reg.coef_
m
# Out:
# array([[20.51541797]])

# %%
c =reg.intercept_
c
# Out:
# array([-9795.69523278])

# %%
y
# Out:
#      rent
# 0   31500
# 1   35000
# 2   41050
# 3   36100
# 4   52100
# 5   32500
# 6   20000
# 7   24500
# 8   48000
# 9   31000
# 10  34500
# 11  32000
# 12  34500
# 13  40050
# 14  34100
# 15  51500
# 16  30500
# 17  21000
# 18  25000
# 19  47000
# 20  31500
# 21  33500
# 22  70000
# 23  20000
# 24  50000
# 25  53000
# 26  48000
# 27  25000
# 28  31460
# 29  51400
# 30  33500
# 31  35010
# 32  41100
# 33  35100
# 34  52200
# 35  32300
# 36  20200
# 37  24000
# 38  47500
# 39  31500
# 40  34400
# 41  32020
# 42  34700
# 43  40000
# 44  35000
# 45  51000
# 46  30000
# 47  21500
# 48  25500
# 49  47500
# 50  31000
# 51  33000
# 52  70500
# 53  20100
# 54  51000
# 55  54000
# 56  48500
# 57  25100
# 58  31560
# 59  51600

# %%
reg.predict([[2100]])
# Out:
# array([[33286.68249842]])

# %%
pred=reg.predict(xtest)
pred
# Out:
# array([[45595.93327876],
#        [27132.05710825],
#        [35338.22429514],
#        [34312.45339678],
#        [27132.05710825],
#        [28157.82800661],
#        [47647.47507549],
#        [33286.68249842],
#        [53802.10046566],
#        [45595.93327876],
#        [33286.68249842],
#        [27132.05710825],
#        [33286.68249842],
#        [35338.22429514],
#        [47647.47507549],
#        [27132.05710825],
#        [62008.26765255],
#        [29183.59890497]])

# %%
df['predicted result'] = reg.predict(x)

# %%
df.head()
# Out:
#    area   rent  predicted result
# 0  2000  31500      31235.140702
# 1  2100  35000      33286.682498
# 2  2500  41050      41492.849685
# 3  2250  36100      36363.995194
# 4  3000  52100      51750.558669

# %%
x1=3000
y =m*x1+c
y
# Out:
# array([[51750.55866893]])

# %%
plt.figure(figsize=(12,8))
plt.scatter(df.area,df.rent)
plt.xlabel('Area')
plt.ylabel('Rent')
plt.title('Best Fit Line')
plt.plot(xtrain,reg.predict(xtrain),color='red')
